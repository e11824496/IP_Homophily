# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import network_generation as homomul
import spread_simulation
from tqdm.notebook import tqdm

# %% [markdown]
# # Spread based on Consolidation and Homophily

# %%
model_settings = {
    'N': 3200, 
    'm': 5, 
    'consolidation_param': 0.1,
    'marginal_distribution': [[0.5,0.5],[0.5,0.5]], 
    'homophily': 0.8, 
    'complex_threshold': 0.16,
    'initial_seed_filter': lambda x: x.nodes
}

experiment_settings = {
    'n_networks': 2,
    'n_initial_seeds': 5
}


spread_simulation.batch_simulate(**model_settings, **experiment_settings)
# Out:
# (0.00596875, 0.0)

# %%
threshold_settings = np.linspace(0.1,0.2,10)
consolidation_settings = np.linspace(0,0.5, 6)

results_average, results_global_spread = spread_simulation.setting_simulate('consolidation_param', consolidation_settings, 
                                                          'complex_threshold', threshold_settings, 
                                                          model_settings, experiment_settings)
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# consolidation_param: 0.00 / complex_threshold: 0.10 => avg = 1.00; global = 1.00
# consolidation_param: 0.00 / complex_threshold: 0.11 => avg = 1.00; global = 1.00
# consolidation_param: 0.00 / complex_threshold: 0.12 => avg = 1.00; global = 1.00
# consolidation_param: 0.00 / complex_threshold: 0.13 => avg = 1.00; global = 1.00
# consolidation_param: 0.00 / complex_threshold: 0.14 => avg = 0.31; global = 0.30
# consolidation_param: 0.00 / complex_threshold: 0.16 => avg = 0.21; global = 0.20
# consolidation_param: 0.00 / complex_threshold: 0.17 => avg = 0.01; global = 0.00
# consolidation_param: 0.00 / complex_threshold: 0.18 => avg = 0.01; global = 0.00
# consolidation_param: 0.00 / complex_threshold: 0.19 => avg = 0.01; global = 0.00
# consolidation_param: 0.00 / complex_threshold: 0.20 => avg = 0.01; global = 0.00
# consolidation_param: 0.10 / complex_threshold: 0.10 => avg = 1.00; global = 1.00
# consolidation_param: 0.10 / complex_threshold: 0.11 => avg = 1.00; global = 1.00
# consolidation_param: 0.10 / complex_threshold: 0.12 => avg = 1.00; global = 1.00
# consolidation_param: 0.10 / complex_threshold: 0.13 => avg = 1.00; global = 1.00
# consolidation_param: 0.10 / complex_threshold: 0.14 => avg = 0.30; global = 0.30
# consolidation_param: 0.10 / complex_threshold: 0.16 => avg = 0.01; global = 0.00
# consolidation_param: 0.10 / complex_threshold: 0.17 => avg = 0.01; global = 0.00
# consolidation_param: 0.10 / complex_threshold: 0.18 => avg = 0.01; global = 0.00
# consolidation_param: 0.10 / complex_threshold: 0.19 => avg = 0.01; global = 0.00
# consolidation_param: 0.10 / complex_threshold: 0.20 => avg = 0.01; global = 0.00
# consolidation_param: 0.20 / complex_threshold: 0.10 => avg = 1.00; global = 1.00
# consolidation_param: 0.20 / complex_threshold: 0.11 => avg = 1.00; global = 1.00
# consolidation_param: 0.20 / complex_threshold: 0.12 => avg = 1.00; global = 1.00
# consolidation_param: 0.20 / complex_threshold: 0.13 => avg = 0.90; global = 0.90
# consolidation_param: 0.20 / complex_threshold: 0.14 => avg = 0.21; global = 0.20
# consolidation_param: 0.20 / complex_threshold: 0.16 => avg = 0.21; global = 0.20
# consolidation_param: 0.20 / complex_threshold: 0.17 => avg = 0.01; global = 0.00
# consolidation_param: 0.20 / complex_threshold: 0.18 => avg = 0.01; global = 0.00
# consolidation_param: 0.20 / complex_threshold: 0.19 => avg = 0.01; global = 0.00
# consolidation_param: 0.20 / complex_threshold: 0.20 => avg = 0.00; global = 0.00
# consolidation_param: 0.30 / complex_threshold: 0.10 => avg = 1.00; global = 1.00
# consolidation_param: 0.30 / complex_threshold: 0.11 => avg = 1.00; global = 1.00
# consolidation_param: 0.30 / complex_threshold: 0.12 => avg = 1.00; global = 1.00
# consolidation_param: 0.30 / complex_threshold: 0.13 => avg = 0.90; global = 0.90
# consolidation_param: 0.30 / complex_threshold: 0.14 => avg = 0.51; global = 0.50
# consolidation_param: 0.30 / complex_threshold: 0.16 => avg = 0.01; global = 0.00
# consolidation_param: 0.30 / complex_threshold: 0.17 => avg = 0.01; global = 0.00
# consolidation_param: 0.30 / complex_threshold: 0.18 => avg = 0.01; global = 0.00
# consolidation_param: 0.30 / complex_threshold: 0.19 => avg = 0.01; global = 0.00
# consolidation_param: 0.30 / complex_threshold: 0.20 => avg = 0.01; global = 0.00
# consolidation_param: 0.40 / complex_threshold: 0.10 => avg = 1.00; global = 1.00
# consolidation_param: 0.40 / complex_threshold: 0.11 => avg = 1.00; global = 1.00
# consolidation_param: 0.40 / complex_threshold: 0.12 => avg = 1.00; global = 1.00
# consolidation_param: 0.40 / complex_threshold: 0.13 => avg = 0.90; global = 0.90
# consolidation_param: 0.40 / complex_threshold: 0.14 => avg = 0.11; global = 0.10
# consolidation_param: 0.40 / complex_threshold: 0.16 => avg = 0.01; global = 0.00
# consolidation_param: 0.40 / complex_threshold: 0.17 => avg = 0.01; global = 0.00
# consolidation_param: 0.40 / complex_threshold: 0.18 => avg = 0.01; global = 0.00
# consolidation_param: 0.40 / complex_threshold: 0.19 => avg = 0.00; global = 0.00
# consolidation_param: 0.40 / complex_threshold: 0.20 => avg = 0.00; global = 0.00
# consolidation_param: 0.50 / complex_threshold: 0.10 => avg = 1.00; global = 1.00
# consolidation_param: 0.50 / complex_threshold: 0.11 => avg = 1.00; global = 1.00
# consolidation_param: 0.50 / complex_threshold: 0.12 => avg = 1.00; global = 1.00
# consolidation_param: 0.50 / complex_threshold: 0.13 => avg = 0.90; global = 0.90
# consolidation_param: 0.50 / complex_threshold: 0.14 => avg = 0.11; global = 0.10
# consolidation_param: 0.50 / complex_threshold: 0.16 => avg = 0.01; global = 0.00
# consolidation_param: 0.50 / complex_threshold: 0.17 => avg = 0.01; global = 0.00
# consolidation_param: 0.50 / complex_threshold: 0.18 => avg = 0.01; global = 0.00
# consolidation_param: 0.50 / complex_threshold: 0.19 => avg = 0.00; global = 0.00
# consolidation_param: 0.50 / complex_threshold: 0.20 => avg = 0.00; global = 0.00
